# %% [markdown]
# # MVC

# %% [markdown]
# MVC把web应用分为三层：模型（M）、视图（V）、控制器（C）
#
# 模型负责业务对象和数据库对象
#
# 视图负责与用户交互
#
# 控制器接受用户的输入调用模型和视图完成用户的请求

# %% [markdown]
# # MTV

# %% [markdown]
# MTV分别是：模型、模板、视图
#
# 模型负责业务对象和数据库对象
#
# 模板负责如何把页面展示给用户
#
# 视图负责业务逻辑，并在适当时候调用模型和模板

# %% [markdown]
# # Django工作流程（借图）

# %% [markdown]
# Django的url分发器将用户请求分发给指定的view进行处理

# %% [markdown]
# ![image.png](attachment:image.png)
